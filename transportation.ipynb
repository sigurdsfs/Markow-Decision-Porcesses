# %%
import os
### Model (MDP problem)

class TransportationMDP(object):
    def __init__(self, N):
        # N = number of blocks
        self.N = N
    def startState(self):
        return 1
    def isEnd(self, state):
        return state == self.N
    def actions(self, state):
        # return list of valid actions
        result = []
        if state+1<=self.N:
            result.append('walk')
        if state*2<=self.N:
            result.append('tram')
        return result
    def succProbReward(self, state, action):
        # return list of (newState, prob, reward) triples
        # state = s, action = a, newState = s'
        # prob = T(s, a, s'), reward = Reward(s, a, s')
        result = []
        if action=='walk':
            result.append((state+1, 1., -1.))
        elif action=='tram':
            failProb = 0.5
            result.append((state*2, 1.-failProb, -2.))
            result.append((state, failProb, -2.))
        return result
    def discount(self):
        return 1.
    def states(self):
        return range(1, self.N+1)

# Inference (Algorithms)

def valueIteration(mdp):
    # initialize
    V = {} # state -> Vopt[state]
    for state in mdp.states():
        V[state] = 0.

    def Q(state, action):
        return sum(prob*(reward + mdp.discount()*V[newState]) \
                for newState, prob, reward in mdp.succProbReward(state, action))

    while True:
        # compute the new values (newV) given the old values (V)
        newV = {}
        for state in mdp.states():
            if mdp.isEnd(state):
                newV[state] = 0.
            else:
                newV[state] = max(Q(state, action) for action in mdp.actions(state))
        # check for convergence
        if max(abs(V[state]-newV[state]) for state in mdp.states())<1e-20:
            break
        V = newV

        # read out policy
        pi = {}
        for state in mdp.states():
            if mdp.isEnd(state):
                pi[state] = 'none'
            else:
                pi[state] = max((Q(state, action), action) for action in mdp.actions(state))[1]

        # print stuff out
        #os.system('clear')
        print('{:15} {:15} {:15}'.format('s', 'V(s)', 'pi(s)'))
        for state in mdp.states():
            print('{:15} {:15} {:15}'.format(state, V[state], pi[state]))
        #input()

# %%
mdp = TransportationMDP(15)
for i in range(15):
    print(mdp.actions(i))
    print(mdp.succProbReward(i,"walk")) 
    if i*2<15:
        print(mdp.succProbReward(i,"tram"))

# %%
#Evaluate and find the best/optimal policy for every state. 
valueIteration(TransportationMDP(10))
# Out:
# s               V(s)            pi(s)
#               1            -1.0 walk
#               2            -1.0 walk
#               3            -1.0 walk
#               4            -1.0 walk
#               5            -1.0 walk
#               6            -1.0 walk
#               7            -1.0 walk
#               8            -1.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1            -2.0 walk
#               2            -2.0 walk
#               3            -2.0 walk
#               4            -2.0 walk
#               5            -2.0 walk
#               6            -2.0 walk
#               7            -2.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1            -3.0 walk
#               2            -3.0 walk
#               3            -3.0 walk
#               4            -3.0 walk
#               5            -3.0 tram
#               6            -3.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1            -4.0 walk
#               2            -4.0 walk
#               3            -4.0 walk
#               4            -4.0 walk
#               5            -3.5 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1            -5.0 walk
#               2            -5.0 walk
#               3            -5.0 walk
#               4            -4.5 walk
#               5           -3.75 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1            -6.0 walk
#               2            -6.0 walk
#               3            -5.5 walk
#               4           -4.75 walk
#               5          -3.875 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1            -7.0 walk
#               2            -6.5 walk
#               3           -5.75 walk
#               4          -4.875 walk
#               5         -3.9375 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1            -7.5 walk
#               2           -6.75 walk
#               3          -5.875 walk
#               4         -4.9375 walk
#               5        -3.96875 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1           -7.75 walk
#               2          -6.875 walk
#               3         -5.9375 walk
#               4        -4.96875 walk
#               5       -3.984375 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1          -7.875 walk
#               2         -6.9375 walk
#               3        -5.96875 walk
#               4       -4.984375 walk
#               5      -3.9921875 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1         -7.9375 walk
#               2        -6.96875 walk
#               3       -5.984375 walk
#               4      -4.9921875 walk
#               5     -3.99609375 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1        -7.96875 walk
#               2       -6.984375 walk
#               3      -5.9921875 walk
#               4     -4.99609375 walk
#               5    -3.998046875 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1       -7.984375 walk
#               2      -6.9921875 walk
#               3     -5.99609375 walk
#               4    -4.998046875 walk
#               5   -3.9990234375 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1      -7.9921875 walk
#               2     -6.99609375 walk
#               3    -5.998046875 walk
#               4   -4.9990234375 walk
#               5  -3.99951171875 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1     -7.99609375 walk
#               2    -6.998046875 walk
#               3   -5.9990234375 walk
#               4  -4.99951171875 walk
#               5 -3.999755859375 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1    -7.998046875 walk
#               2   -6.9990234375 walk
#               3  -5.99951171875 walk
#               4 -4.999755859375 walk
#               5 -3.9998779296875 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1   -7.9990234375 walk
#               2  -6.99951171875 walk
#               3 -5.999755859375 walk
#               4 -4.9998779296875 walk
#               5 -3.99993896484375 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1  -7.99951171875 walk
#               2 -6.999755859375 walk
#               3 -5.9998779296875 walk
#               4 -4.99993896484375 walk
#               5 -3.999969482421875 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.999755859375 walk
#               2 -6.9998779296875 walk
#               3 -5.99993896484375 walk
#               4 -4.999969482421875 walk
#               5 -3.9999847412109375 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.9998779296875 walk
#               2 -6.99993896484375 walk
#               3 -5.999969482421875 walk
#               4 -4.9999847412109375 walk
#               5 -3.9999923706054688 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.99993896484375 walk
#               2 -6.999969482421875 walk
#               3 -5.9999847412109375 walk
#               4 -4.999992370605469 walk
#               5 -3.9999961853027344 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.999969482421875 walk
#               2 -6.9999847412109375 walk
#               3 -5.999992370605469 walk
#               4 -4.999996185302734 walk
#               5 -3.999998092651367 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.9999847412109375 walk
#               2 -6.999992370605469 walk
#               3 -5.999996185302734 walk
#               4 -4.999998092651367 walk
#               5 -3.9999990463256836 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.999992370605469 walk
#               2 -6.999996185302734 walk
#               3 -5.999998092651367 walk
#               4 -4.999999046325684 walk
#               5 -3.999999523162842 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.999996185302734 walk
#               2 -6.999998092651367 walk
#               3 -5.999999046325684 walk
#               4 -4.999999523162842 walk
#               5 -3.999999761581421 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.999998092651367 walk
#               2 -6.999999046325684 walk
#               3 -5.999999523162842 walk
#               4 -4.999999761581421 walk
#               5 -3.9999998807907104 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.999999046325684 walk
#               2 -6.999999523162842 walk
#               3 -5.999999761581421 walk
#               4 -4.9999998807907104 walk
#               5 -3.9999999403953552 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.999999523162842 walk
#               2 -6.999999761581421 walk
#               3 -5.9999998807907104 walk
#               4 -4.999999940395355 walk
#               5 -3.9999999701976776 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.999999761581421 walk
#               2 -6.9999998807907104 walk
#               3 -5.999999940395355 walk
#               4 -4.999999970197678 walk
#               5 -3.999999985098839 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.9999998807907104 walk
#               2 -6.999999940395355 walk
#               3 -5.999999970197678 walk
#               4 -4.999999985098839 walk
#               5 -3.9999999925494194 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.999999940395355 walk
#               2 -6.999999970197678 walk
#               3 -5.999999985098839 walk
#               4 -4.999999992549419 walk
#               5 -3.9999999962747097 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.999999970197678 walk
#               2 -6.999999985098839 walk
#               3 -5.999999992549419 walk
#               4 -4.99999999627471 walk
#               5 -3.999999998137355 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.999999985098839 walk
#               2 -6.999999992549419 walk
#               3 -5.99999999627471 walk
#               4 -4.999999998137355 walk
#               5 -3.9999999990686774 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.999999992549419 walk
#               2 -6.99999999627471 walk
#               3 -5.999999998137355 walk
#               4 -4.999999999068677 walk
#               5 -3.9999999995343387 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.99999999627471 walk
#               2 -6.999999998137355 walk
#               3 -5.999999999068677 walk
#               4 -4.999999999534339 walk
#               5 -3.9999999997671694 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.999999998137355 walk
#               2 -6.999999999068677 walk
#               3 -5.999999999534339 walk
#               4 -4.999999999767169 walk
#               5 -3.9999999998835847 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.999999999068677 walk
#               2 -6.999999999534339 walk
#               3 -5.999999999767169 walk
#               4 -4.999999999883585 walk
#               5 -3.9999999999417923 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.999999999534339 walk
#               2 -6.999999999767169 walk
#               3 -5.999999999883585 walk
#               4 -4.999999999941792 walk
#               5 -3.999999999970896 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.999999999767169 walk
#               2 -6.999999999883585 walk
#               3 -5.999999999941792 walk
#               4 -4.999999999970896 walk
#               5 -3.999999999985448 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.999999999883585 walk
#               2 -6.999999999941792 walk
#               3 -5.999999999970896 walk
#               4 -4.999999999985448 walk
#               5 -3.999999999992724 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.999999999941792 walk
#               2 -6.999999999970896 walk
#               3 -5.999999999985448 walk
#               4 -4.999999999992724 walk
#               5 -3.999999999996362 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.999999999970896 walk
#               2 -6.999999999985448 walk
#               3 -5.999999999992724 walk
#               4 -4.999999999996362 walk
#               5 -3.999999999998181 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.999999999985448 walk
#               2 -6.999999999992724 walk
#               3 -5.999999999996362 walk
#               4 -4.999999999998181 walk
#               5 -3.9999999999990905 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.999999999992724 walk
#               2 -6.999999999996362 walk
#               3 -5.999999999998181 walk
#               4 -4.9999999999990905 walk
#               5 -3.9999999999995453 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.999999999996362 walk
#               2 -6.999999999998181 walk
#               3 -5.9999999999990905 walk
#               4 -4.999999999999545 walk
#               5 -3.9999999999997726 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.999999999998181 walk
#               2 -6.9999999999990905 walk
#               3 -5.999999999999545 walk
#               4 -4.999999999999773 walk
#               5 -3.9999999999998863 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.9999999999990905 walk
#               2 -6.999999999999545 walk
#               3 -5.999999999999773 walk
#               4 -4.999999999999886 walk
#               5 -3.999999999999943 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.999999999999545 walk
#               2 -6.999999999999773 walk
#               3 -5.999999999999886 walk
#               4 -4.999999999999943 walk
#               5 -3.9999999999999716 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.999999999999773 walk
#               2 -6.999999999999886 walk
#               3 -5.999999999999943 walk
#               4 -4.999999999999972 walk
#               5 -3.999999999999986 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.999999999999886 walk
#               2 -6.999999999999943 walk
#               3 -5.999999999999972 walk
#               4 -4.999999999999986 walk
#               5 -3.999999999999993 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.999999999999943 walk
#               2 -6.999999999999972 walk
#               3 -5.999999999999986 walk
#               4 -4.999999999999993 walk
#               5 -3.9999999999999964 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.999999999999972 walk
#               2 -6.999999999999986 walk
#               3 -5.999999999999993 walk
#               4 -4.9999999999999964 walk
#               5 -3.9999999999999982 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.999999999999986 walk
#               2 -6.999999999999993 walk
#               3 -5.9999999999999964 walk
#               4 -4.999999999999998 walk
#               5 -3.999999999999999 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.999999999999993 walk
#               2 -6.9999999999999964 walk
#               3 -5.999999999999998 walk
#               4 -4.999999999999999 walk
#               5 -3.9999999999999996 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.9999999999999964 walk
#               2 -6.999999999999998 walk
#               3 -5.999999999999999 walk
#               4            -5.0 walk
#               5            -4.0 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.999999999999998 walk
#               2 -6.999999999999999 walk
#               3            -6.0 walk
#               4            -5.0 walk
#               5            -4.0 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1 -7.999999999999999 walk
#               2            -7.0 walk
#               3            -6.0 walk
#               4            -5.0 walk
#               5            -4.0 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
# s               V(s)            pi(s)
#               1            -8.0 walk
#               2            -7.0 walk
#               3            -6.0 walk
#               4            -5.0 walk
#               5            -4.0 tram
#               6            -4.0 walk
#               7            -3.0 walk
#               8            -2.0 walk
#               9            -1.0 walk
#              10             0.0 none
